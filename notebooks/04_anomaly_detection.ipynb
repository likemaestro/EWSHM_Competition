# %% [markdown]
# # 04 -- Anomaly Detection
#
# **Status: TODO**
#
# This notebook will demonstrate unsupervised anomaly and trend detection:
#
# - Dimensionality reduction (PCA, autoencoders)
# - Outlier detection (Isolation Forest, LOF)
# - Statistical process control (control charts)
# - Trend analysis across the five monthly datasets
#
# **Important:** The dataset has no labels. All methods must be
# unsupervised (challenge rules).
#
# The actual logic will live in `aquinas_toolkit.training`;
# this notebook just calls it and visualises the results.

# %%
# TODO: implement unsupervised models in aquinas_toolkit/training/
# then demonstrate them here
