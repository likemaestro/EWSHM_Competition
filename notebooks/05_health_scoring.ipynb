# %% [markdown]
# # 05 -- Health Scoring
#
# **Status: TODO**
#
# This notebook will demonstrate the final health score computation:
#
# - Per-sensor anomaly score aggregation
# - Cross-sensor weighted combination into a global health indicator
# - Trend quantification: stable, improving, or degrading?
# - Confidence / uncertainty bounds
# - Final visualisation of the structural health score over time
#
# This is the key deliverable: a **synthetic health score** indicating
# the stability of the observed mechanical behaviour (challenge rules).
#
# The actual logic will live in `aquinas_toolkit.scoring`;
# this notebook just calls it and visualises the results.

# %%
# TODO: implement health scoring in aquinas_toolkit/scoring.py
# then demonstrate it here
